# %% [markdown]
# Prediction using Decision Tree Algorithm

# %%
#Importhing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the dataset
df=pd.read_csv(r'C:\Users\Admin\Desktop\Kerfegar\Analytics&ML\Projects\SPARK GRIP Internship\Task6\Iris.csv')
df=df.drop('Id',axis=1)
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#Deriving generic information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
#Deriving general statistics
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
#Plotting the counts of distinct species
df['Species'].nunique()
plt.bar(x=df['Species'],height=2)
# Out:
# <BarContainer object of 150 artists>

# %%
#Generating and plotting Co-Relation matrix
print(df.corr())
sns.heatmap(df.corr(),annot=True)
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000
# <AxesSubplot:>

# %%
#Plotting paitplot
sns.pairplot(df,hue='Species')

# %%
#Deriving value distributions of the feature variables
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.stripplot(x ='Species',y='SepalLengthCm',data=df)
plt.subplot(2,2,2)
sns.stripplot(x ='Species',y='SepalWidthCm',data=df)
plt.subplot(2,2,3)
sns.stripplot(x ='Species',y='PetalLengthCm',data=df)
plt.subplot(2,2,4)
sns.stripplot(x ='Species',y = 'PetalWidthCm',data=df)
plt.show()

# %%
#Plotting the relation between feature variables
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
sns.scatterplot(x ='SepalLengthCm',y = 'SepalWidthCm',hue="Species",data=df)
plt.subplot(1,2,2)
sns.scatterplot(x ='PetalLengthCm',y = 'PetalWidthCm',hue="Species",data=df)
plt.show()

# %%
#Splitting the data into feature and target variables
y = df['Species']
x = df.drop(['Species'],axis=1)

# %%
#Splitting the datta into training and testing
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x, y, test_size = 0.2)

# %%
#importing the model
from sklearn.tree import DecisionTreeClassifier
sc=[]
#Finding the optimum max depth of the decision tree
for i in range(1,200):
    model=DecisionTreeClassifier(max_depth=i)
    model.fit(xtrain,ytrain)
    sc.append(model.score(xtest,ytest))

# %%
#Plotting for optimum max depth of the decision tree
plt.plot(range(1,200),sc)
plt.xlabel("Max Depth")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %%
#Fiting the decision tree for a max depth of 3(optimum max depth)
model=DecisionTreeClassifier(max_depth=3)
model.fit(xtrain,ytrain)
model.score(xtest,ytest)
# Out:
# 0.9333333333333333

# %%
#Generating predictions
ypreds=model.predict(xtest)
#Comparing the actual and predicted values
comp=pd.DataFrame({"Actual":ytest,"Predicted":ytest})
comp
# Out:
#               Actual        Predicted
# 135   Iris-virginica   Iris-virginica
# 42       Iris-setosa      Iris-setosa
# 35       Iris-setosa      Iris-setosa
# 39       Iris-setosa      Iris-setosa
# 47       Iris-setosa      Iris-setosa
# 38       Iris-setosa      Iris-setosa
# 119   Iris-virginica   Iris-virginica
# 126   Iris-virginica   Iris-virginica
# 45       Iris-setosa      Iris-setosa
# 76   Iris-versicolor  Iris-versicolor
# 8        Iris-setosa      Iris-setosa
# 129   Iris-virginica   Iris-virginica
# 17       Iris-setosa      Iris-setosa
# 29       Iris-setosa      Iris-setosa
# 78   Iris-versicolor  Iris-versicolor
# 94   Iris-versicolor  Iris-versicolor
# 33       Iris-setosa      Iris-setosa
# 145   Iris-virginica   Iris-virginica
# 22       Iris-setosa      Iris-setosa
# 71   Iris-versicolor  Iris-versicolor
# 102   Iris-virginica   Iris-virginica
# 82   Iris-versicolor  Iris-versicolor
# 15       Iris-setosa      Iris-setosa
# 132   Iris-virginica   Iris-virginica
# ...

# %%
#Deriving the confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(ytest,ypreds)
# Out:
# array([[14,  0,  0],
#        [ 0,  8,  0],
#        [ 0,  2,  6]], dtype=int64)

# %%
#Visualising the decision tree
from sklearn import tree
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(15,10))
tree.plot_tree(model,feature_names=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'] ,
               class_names = df['Species'].unique(), filled=True)
plt.show()
